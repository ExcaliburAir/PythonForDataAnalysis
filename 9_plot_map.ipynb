# %%
# matplotlib API入门

import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
# Figure和Subplot
    # matplotlib的图像都位于Figure对象中。
fig = plt.figure()

# 不能通过空Figure绘图，必须用add_subplot创建一个或多个subplot才行
ax1 = fig.add_subplot(2, 2, 1) # 图像是2x2的，当前是第一个
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.gcf() # 得到当前应用，画图

# %%
# 指令默认会在最后一个图上创建
from numpy.random import randn
plt.plot(randn(50).cumsum(), 'k--') # k--表示黑色虚线图
plt.gcf()

# %%
# add_subplot所返回的对象是AxesSubplot对象，直接调用他们的实力方法可以在其他格子里看到
_ = ax1.hist(randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))
plt.gcf()

# %%
fig, axes = plt.subplots(2, 3)
axes

# pyplot.subplots选项
'''
nrows subplot的行数
ncols subplot的列数
sharex 所有subplot应该使用相同的X轴刻度
sharey 所有subplot应该使用相同的Y轴刻度
subplot_kw 用于创建各subplot的关键字字典
**fig_kw 创建figure时的其他关键字，如plt.subplots(2, 2, figsize=(8, 6))
'''
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1096c6cd0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10980cdd0>]], dtype=object)

# %%
# 调整subplot周围的间距，Figure的subplots_adjust方法
#subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)
plt.gcf()

# %%
# 颜色，标记和线性
ax.plot(x, y, 'g--')
ax.plot(x, y, linestyle='--', color='g')
plt.plot(randn(30).cumsum(), 'ko--')
plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-5d5f06f3bcb3> in <module>()
#       1 # 颜色，标记和线性
# ----> 2 ax.plot(x, y, 'g--')
#
# NameError: name 'ax' is not defined

# %%
data = randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.gcf()

# %%
plt.plot(data, 'k--', drawstyle='steps-post', label='steps-post')
plt.gcf()

# %%
plt.legend(loc='best')
plt.gcf()

# %%
# 刻度，标签和图利
'''
* 调用时不待参数，则返回当前的参数值。例如，plt.xlim()放回当前的X轴绘图范围。
* 调用时带参数，则设置参数值。因此，plt.xlim([0, 10])会将X轴的范围设置为0到10.
'''

# %%
# 设置标题，轴标签，刻度以及刻度标签
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.gcf()

# %%
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')
plt.gcf()

# %%
# 添加图例
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
plt.gcf()

# %%
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')
ax.legend(loc='best')
plt.gcf()

# %%
# 注解以及在Subplot上绘图
ax.text(x, y, 'Hello world!', family='monospace', fontsize=10)

from datetime import datetime
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('aaa', index_col=0, parse_dates=True)
spx = data['SPX']
spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datatime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9,15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(data, spx.asof(data) + 50),
               xytext=(data, spx.asof(date) + 200),
               arrowprops=dict(facecolor='black'),
               horizontalalignment='left',
               verticalalignment='top')

ax.set_xlim(['1/1/2007', '1/1/2001'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in 2008-2009 financial crisis')

fig = plt.figure()
ax = fig.add_suplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='g', alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-b6da51924ff0> in <module>()
#       1 # 注解以及在Subplot上绘图
# ----> 2 ax.text(x, y, 'Hello world!', family='monospace', fontsize=10)
#       3
#       4 from datetime import datetime
#       5 fig = plt.figure()
#
# NameError: name 'x' is not defined

# %%
# 将图表保存到文件
plt.savefig('figpath.svg')
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

from io import StringIO
buffer = StringIO()
plt.savefig(buffer)
plot_data = buffer.getvalue()

# Figure.savefig选项
'''
fname 含有文件路径的字符串或Python的文件型对象。图片格式由文件扩展名推断得出，例如，.pdf推断出PDF，.png推断出PNG
dpi 图像分辨率（每英寸点数），默认为100
facecolor，edgecolor 图像的背景色，默认为“W”
format 模式设置文件格式
bbox_inches 图表需要保存的部分。如果设置为“tight”，则尝试剪除图表周围的空白部分
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-5c5a6bc00fb9> in <module>()
#       5 from io import StringIO
#       6 buffer = StringIO()
# ----> 7 plt.savefig(buffer)
#       8 plot_data = buffer.getvalue()
#       9
#
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     699 def savefig(*args, **kwargs):
#     700     fig = gcf()
# --> 701     res = fig.savefig(*args, **kwargs)
#     702     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     703     return res
#
# /usr/local/lib/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, fname, **kwargs)
#    1832             self.set_frameon(frameon)
#    1833
# -> 1834         self.canvas.print_figure(fname, **kwargs)
#    1835
#    1836         if frameon:
#
# ...

# %%
# matplotlib配置
plt.rc('figure', figsize=(10, 10))
font_options = {
    'family': 'monospace',
    'weight': 'bold',
    'size': 'small'
}
plt.rc('font', **font_options)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-f31f89cb36d4> in <module>()
#       6     'size': 'small'
#       7 }
# ----> 8 plt.rc('font', **font_options)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in rc(*args, **kwargs)
#     302 @docstring.copy_dedent(matplotlib.rc)
#     303 def rc(*args, **kwargs):
# --> 304     matplotlib.rc(*args, **kwargs)
#     305
#     306
#
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.pyc in rc(group, **kwargs)
#    1156             key = '%s.%s' % (g, name)
#    1157             try:
# -> 1158                 rcParams[key] = v
#    1159             except KeyError:
#    1160                 raise KeyError(('Unrecognized key "%s" for group "%s" and '
#
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.pyc in __setitem__(self, key, val)
# ...

# %%
# pandas中的绘图函数
# 线型图
s = Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()
plt.gcf()

# Series.plot方法的参数
'''
label 用于图例的标签
ax 要在其上进行绘制的matplotlib subplot对象，如果没有设置，则使用当前matplotlib subplot
style 将要传给matplotlib的风格字符串
alpha 图表的填充不不透明度
kind 可以是‘line’，‘bar’，‘barh’，‘kde’
logy 在Y轴上使用多数标尺
use_index 将对象的索引用作刻度标签
rot 旋转刻度标签
xticks 用作X轴刻度的值
yticks 用作Y轴制度的值
xlim X轴的界限
ylim Y轴的极限
grid 显示轴网格线
'''

# 专用语DataFrame的plot的参数
'''
subplots 将各个DataFrame列绘制到单独的subplot中
sharex 如果suplots=True，则共用同一X轴，包括刻度和界限
sharey 如果subplots=True，则共用同一个Y轴
figsize 表示图像大小的元组
title 表示图像标题的字符串
legend 添加一个subplot图例
sort_columns 以字母表顺序检测各列，默认使用当前列顺序
'''

# %%
# 柱状图
    # 在生成线型图的代码中kind=‘bar’或kind=‘barh’。垂直柱状图，水平柱状图
    
fig, axes = plt.subplots(2, 1)
data = Series(np.random.rand(16), index=list('abcdefghijklmop'))
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)
data.plot(kind='barh', ax=axes[1], color='k', alpha=0.7)
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-fecf6696866c> in <module>()
#       3
#       4 fig, axes = plt.subplots(2, 1)
# ----> 5 data = Series(np.random.rand(16), index=list('abcdefghijklmop'))
#       6 data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)
#       7 data.plot(kind='barh', ax=axes[1], color='k', alpha=0.7)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
# ...

# %%
df = DataFrame(np.random.rand(6, 4), 
               index=['one', 'two', 'three', 'four', 'five', 'six'], 
               columns=pd.Index(['A', 'B', 'C', 'D'], names='Genus'))
df
df.plot(kind='bar')
plt.gcf()

# %%
df.plot(kind='barh', stacked=True, alpha=0.5)
tips = pd.read_csv('')
party_counts = pd.crosstab(tips.day, tips.size)
party_counts
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-46-c8d33cf65ce5> in <module>()
#       1 df.plot(kind='barh', stacked=True, alpha=0.5)
# ----> 2 tips = pd.read_csv('')
#       3 party_counts = pd.crosstab(tips.day, tips.size)
#       4 party_counts
#
# ...

# %%
# 直方图和密度图
#tips['tip_pct'].plot(kind='kde')
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)
values = Series(np.concatenate([comp1, comp2]))
values.hist(bins=100, alpha=0.3, color='k', normed=True)
values.plot(kind='kde', style='k--')
plt.gcf()

# %%
# 散布图
macro = pd.read_csv('')
data = macro[['cpi', 'm1', 'tbiIrate', 'unemp']]
trans_data = np.log(data).diff().dropna()
trans_data[-5:]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-51-67840db12b0d> in <module>()
#       1 # 散布图
# ----> 2 macro = pd.read_csv('')
#       3 data = macro[['cpi', 'm1', 'tbiIrate', 'unemp']]
#       4 trans_data = np.log(data).diff().dropna()
#       5 trans_data[-5:]
#
# ...

# %%
plt.scatter(trans_data['m1'], trns_data['unemp'])
plt.title('Changes in log %s vs. log %s' % ('n1', 'unemp'))
pd.scatter_matrix(trans_data, diagonal='kde', color='k', alpha=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-f73faa6bfe6b> in <module>()
# ----> 1 plt.scatter(trans_data['m1'], trns_data['unemp'])
#       2 plt.title('Changes in log %s vs. log %s' % ('n1', 'unemp'))
#       3 pd.scatter_matrix(trans_data, diagonal='kde', color='k', alpha=0.3)
#
# NameError: name 'trans_data' is not defined

# %%
# 绘制地图：图形化显示海地地震危机数据
data = data[(data.LATITUDE > 18) & 
            (data.LATITUDE < 20) & 
            (data.LONGITUDE > -75) & 
            (data.LONGITUDE < -70) & 
            data.CATEGORY.notnull()]

def to_cat_list(catstr):
    stripped = (x.strip() for x in catstr.split(','))
    return [x for x in stripped if x]

def get_all_categories(cat_series):
    cat_sets = (set(to_cat_list(x)) for x in cat_series)
    return sorted(set.union(*cat_sets))

def get_english(cat):
    code, names = cat.split(',')
    if '|' in names:
        names = names.split('|')[1]
    return code, names.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-8fcdc92d0e1b> in <module>()
#       3             (data.LATITUDE < 20) &
#       4             (data.LONGITUDE > -75) &
# ----> 5             (data.LONGITUDE < -70) &
#       6             data.CATEGORY.notnull()]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'LATITUDE'

# %%
# Python图形化工具生态系统
'''
Chaco
mayavi
...
'''
